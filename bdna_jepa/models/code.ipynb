# %%
import pandas as pd
df = pd.read_csv("../data/nhac/NHAC_deduplicated.csv")
print(df.shape)
print(df["label"].value_counts())
print(df["set"].value_counts())
print(df["seq_31"].str.len().describe())
